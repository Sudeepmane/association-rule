# %%
import pandas as pd

# %%
df=pd.read_csv("Online retail.csv",header=None,names=['customer_purchase'])
df.head()
# Out:
#                                    customer_purchase
# 0  shrimp,almonds,avocado,vegetables mix,green gr...
# 1                             burgers,meatballs,eggs
# 2                                            chutney
# 3                                     turkey,avocado
# 4  mineral water,milk,energy bar,whole wheat rice...

# %%
df=pd.DataFrame(df)
df['customer_purchase'] = df['customer_purchase'].apply(lambda x: x.split(','))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7501 entries, 0 to 7500
# Data columns (total 1 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer_purchase  7501 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB

# %%
df.shape
# Out:
# (7501, 1)

# %%
df.head()
# Out:
#                                    customer_purchase
# 0  [shrimp, almonds, avocado, vegetables mix, gre...
# 1                         [burgers, meatballs, eggs]
# 2                                          [chutney]
# 3                                  [turkey, avocado]
# 4  [mineral water, milk, energy bar, whole wheat ...

# %%
transaction = df['customer_purchase'].tolist()

# %%
transaction
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
transaction[0]
# Out:
# ['shrimp',
#  'almonds',
#  'avocado',
#  'vegetables mix',
#  'green grapes',
#  'whole weat flour',
#  'yams',
#  'cottage cheese',
#  'energy drink',
#  'tomato juice',
#  'low fat yogurt',
#  'green tea',
#  'honey',
#  'salad',
#  'mineral water',
#  'salmon',
#  'antioxydant juice',
#  'frozen smoothie',
#  'spinach',
#  'olive oil']

# %%
transaction[99]
# Out:
# ['frozen vegetables',
#  'whole wheat pasta',
#  'ground beef',
#  'spaghetti',
#  'chocolate',
#  'green tea']

# %%
transaction[3]
# Out:
# ['turkey', 'avocado']

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Converting transactions to columns using transacationEncoder
te = TransactionEncoder()
te
te_ary = te.fit_transform(transaction)
dataset = pd.DataFrame(te_ary, columns=te.columns_)
dataset
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
te
# Out:
# TransactionEncoder()

# %%
te_ary = te.fit_transform(transaction)
te_ary
# Out:
# array([[False,  True,  True, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
dataset = pd.DataFrame(te_ary, columns=te.columns_)
dataset
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
#STEP8:# Convert dataset into 1-0 encoding
def encode_units(x):
    if x == False:
        return 0 
    if x == True:
        return 1
